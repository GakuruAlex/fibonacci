# %%
from fibonacci import fib_iter, fib_recur, fib_mem

# %%
# %%timeit
fib_iter(1000)
# Out:
# 218 μs ± 20.3 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
fib_recur(30)
# Out:
# 233 ms ± 7.12 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
fib_mem(1000)
# Out:
# 119 ns ± 4.89 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)
