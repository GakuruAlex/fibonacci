# %%
from fibonacci import fib_iter, fib_recur, fib_mem

# %%
# %%timeit
fib_iter(20)
# Out:
# 2.89 μs ± 71.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%timeit
fib_recur(20)
# Out:
# 1.5 ms ± 55 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
fib_mem(20)
# Out:
# 102 ns ± 6.19 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)
